# %%
'''
Getting ward for a given address, the wards are the conformed dimension. That means is the column where we can
connect each of the datasets together, each share a Ward. You can look up on what Ward you are in by typing in your
address on a website. We need to refomat some columns so it is suitable to type in. 

Then we can visually explore the data

''' 
from selenium import webdriver
import time
import pandas as pd
import numpy as np

## importing data
col_list = ["_id", "DATE_SUBMITTED", "STREET_DIRECTION", "STREET_NAME","STREET_NUM", "STREET_TYPE"]
df = pd.read_csv('data/csv/Development_Applications_Data.csv', usecols=col_list)  

df
# Out:
#           _id DATE_SUBMITTED STREET_DIRECTION      STREET_NAME STREET_NUM  \
# 0      540631     2017-11-10                E             KING         65
# 1      540632     2018-07-06                             YONGE       1506
# 2      540633     2018-07-06                   TEDDINGTON PARK         50
# 3      540634     2018-05-31                            AVENUE        620
# 4      540635     2018-05-31                    SOUTH KINGSWAY        209
# ...       ...            ...              ...              ...        ...
# 29894  603148     2016-05-04                               BAY        967
# 29895  603149     2019-02-01                            GILDER      31-85
# 29896  603150     2019-03-01                            GILDER      31-85
# 29897  603154     2018-06-01                          MASTWOOD         16
# 29898  603157     2016-03-07                            CATHER          1
#
#       STREET_TYPE
# 0              ST
# 1              ST
# 2             AVE
# 3              RD
# 4
# ...           ...
# 29894          ST
# 29895          DR
# 29896          DR
# 29897        CRES
# 29898        CRES
#
# [29899 rows x 6 columns]

# %%
# Creating an address that we can find a ward
df["Address"] = df["STREET_NUM"] + " " + df["STREET_NAME"] + " " + df["STREET_TYPE"] + " " + df["STREET_DIRECTION"]

df
# Out:
#           _id DATE_SUBMITTED STREET_DIRECTION      STREET_NAME STREET_NUM  \
# 0      540631     2017-11-10                E             KING         65
# 1      540632     2018-07-06                             YONGE       1506
# 2      540633     2018-07-06                   TEDDINGTON PARK         50
# 3      540634     2018-05-31                            AVENUE        620
# 4      540635     2018-05-31                    SOUTH KINGSWAY        209
# ...       ...            ...              ...              ...        ...
# 29894  603148     2016-05-04                               BAY        967
# 29895  603149     2019-02-01                            GILDER      31-85
# 29896  603150     2019-03-01                            GILDER      31-85
# 29897  603154     2018-06-01                          MASTWOOD         16
# 29898  603157     2016-03-07                            CATHER          1
#
#       STREET_TYPE                   Address
# 0              ST              65 KING ST E
# 1              ST           1506 YONGE ST
# 2             AVE  50 TEDDINGTON PARK AVE
# 3              RD           620 AVENUE RD
# 4                    209 SOUTH KINGSWAY
# ...           ...                       ...
# 29894          ST              967 BAY ST
# 29895          DR         31-85 GILDER DR
# 29896          DR         31-85 GILDER DR
# 29897        CRES        16 MASTWOOD CRES
# 29898        CRES           1 CATHER CRES
#
# [29899 rows x 7 columns]

# %%
# Dropping duplicates and No complete addresses
df.drop_duplicates(subset ="Address", keep = False, inplace = True) 
df.dropna(subset = ["Address"], inplace=True)

# %%
# Creating a table that has 16011 addresses to look up instead of 29899 or a 47% reduction
df
# Out:
#           _id DATE_SUBMITTED STREET_DIRECTION     STREET_NAME STREET_NUM  \
# 1      540632     2018-07-06                            YONGE       1506
# 4      540635     2018-05-31                   SOUTH KINGSWAY        209
# 5      540636     2018-06-19                W           BLOOR       3832
# 6      540637     2018-03-28                          TORYORK        151
# 9      540640     2019-10-15                          MARKHAM       3250
# ...       ...            ...              ...             ...        ...
# 29884  603121     2016-06-10                         HILLSIDE         80
# 29887  603126     2019-12-24                W            KING    401-409
# 29891  603142     2015-10-13                        JEFFERSON         65
# 29894  603148     2016-05-04                              BAY        967
# 29897  603154     2018-06-01                         MASTWOOD         16
#
#       STREET_TYPE                 Address
# 1              ST         1506 YONGE ST
# 4                  209 SOUTH KINGSWAY
# 5              ST         3832 BLOOR ST W
# 6              DR        151 TORYORK DR
# 9              RD       3250 MARKHAM RD
# ...           ...                     ...
# 29884         AVE       80 HILLSIDE AVE
# 29887          ST       401-409 KING ST W
# 29891         AVE      65 JEFFERSON AVE
# 29894          ST            967 BAY ST
# 29897        CRES      16 MASTWOOD CRES
#
# [16011 rows x 7 columns]

# %%
'''
Ideally we would have access to an API however we are going to have to use 
growth hacking tactics in an automated fashion

'''
addresses = df["Address"]

browser = webdriver.Chrome()
browser.get("https://www.toronto.ca/city-government/data-research-maps/neighbourhoods-communities/ward-profiles/")

searcheElement = browser.find_element_by_css_selector("#js_input__address")
array = []
for element in addresses:
    searcheElement.send_keys(element)
    searcheElement.submit() 
    time.sleep(1)
    try:
        linkElement = browser.find_element_by_css_selector(".map--result-text li:nth-child(1) > a")
        linkElement.click()
        searcheElement.clear() 
    except:
        try :
            wardNumElement = browser.find_element_by_css_selector(".map--ward-number")
            array.append(wardNumElement.text)
            searcheElement.clear()
            time.sleep(1)
        except:
            print("An exception occurred - Ward cannot be found")
            searcheElement.clear()
            array.append("0")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-19-f5cb6b600ddc> in <module>
#      12 array = []
#      13 for element in addresses:
# ---> 14     searcheElement.send_keys(element)
#      15     searcheElement.submit()
#      16     time.sleep(1)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in send_keys(self, *value)
#     477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
# --> 479                        'value': keys_to_typing(value)})
#     480
#     481     # RenderedWebElement Items
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=83.0.4103.116)

# %%
ward_df = pd.DataFrame(data, index=["Ward"]

# %%
# appending two dataframes
result = pd.concat([df1, df4], axis=1, sort=False)

# %%
'''
Ideally we would have access to an API however we are going to have to use 
growth hacking tactics in an automated fashion

'''
from multiprocessing import Pool

addresses = df["Address"]

browser = webdriver.Chrome()
browser.get("https://www.toronto.ca/city-government/data-research-maps/neighbourhoods-communities/ward-profiles/")


searcheElement = browser.find_element_by_css_selector("#js_input__address")
array = []
for element in addresses:
    searcheElement.send_keys(element)
    searcheElement.submit() 
    time.sleep(1)
    try:
        linkElement = browser.find_element_by_css_selector(".map--result-text li:nth-child(1) > a")
        linkElement.click()
        searcheElement.clear() 
    except:
        try :
            wardNumElement = browser.find_element_by_css_selector(".map--ward-number")
            array.append(wardNumElement.text)
            searcheElement.clear()
            time.sleep(1)
        except:
            print("An exception occurred - Ward cannot be found")
            searcheElement.clear()
            array.append("0")

# %%
results = ThreadPool(8).imap_unordered(fetch_url, urls)
for path in results:
    print(path)

print(f"Elapsed Time: {timer() - start}")

# %%
from multiprocessing import Pool
import requests
from bs4 import BeautifulSoup

# %%
base_url = 'https://www.amazon.ca/b/ref=gbps_img_s-4_4687_6be0a4f4?node=21212970011&smid=A2BAPNBZ2I6I6N&pf_rd_p=94f5d859-22fc-430f-80cf-910fd4644687&pf_rd_s=slot-4&pf_rd_t=701&pf_rd_i=gb_main&pf_rd_m=A3DWYIK6Y9EEQB&pf_rd_r=CC4QD66GSSV8J5C825F4'

all_urls = list()

print("Getting data")

# getting a list of strings
def generate_urls():
    for i in range(1,11):
        all_urls.append(base_url + str(i))

#going to get them
def scrape(url):
    res = requests.get(url)
    print(res.status_code, res.url)

print("Before")

#calling the function
generate_urls()

# 10 will be processed at a time
p = Pool(10)

p.map(scrape, all_urls)
p.terminate()
p.join()

# %%
p

# %%
import time
from multiprocessing import Pool

# %%
def sum_square(number):
    s = 0
    for i in range(number):
        s += i * i
    return s

if __name__ == '__main__':
    numbers = range(5)

    p = Pool()
    result = p.map(sum_square, numbers)
    print(result)
    p.close()
    p.join()

# %%
import os
import requests
from time import time as timer

# %%
def fetch_url(entry):
    path = entry
    if not os.path.exists(path):
        r = requests.get(uri, stream=True)
        if r.status_code == 200:
            with open(path, 'w+') as f:
                for chunk in r:
                    f.write(chunk)
    return path

# %%
from multiprocessing.pool import ThreadPool

# %%
results = ThreadPool(8).imap_unordered(fetch_url, urls)
for path in results:
    print(path)

print(f"Elapsed Time: {timer() - start}")

# %%
import time, os 
from threading import Thread, current_thread 
from multiprocessing import Process, current_process 


COUNT = 200000000
SLEEP = 10

def io_bound(sec): 

    pid = os.getpid() 
    threadName = current_thread().name 
    processName = current_process().name 

    print(f"{pid} * {processName} * {threadName} --> Start sleeping...") 
    time.sleep(sec) 
    print(f"{pid} * {processName} * {threadName} --> Finished sleeping...") 

def cpu_bound(n): 

    pid = os.getpid() 
    threadName = current_thread().name 
    processName = current_process().name 

    print(f"{pid} * {processName} * {threadName} --> Start counting...") 

    while n>0: 
        n -= 1

    print(f"{pid} * {processName} * {threadName} --> Finished counting...") 

if __name__=="__main__": 
    start = time.time() 

    # YOUR CODE SNIPPET HERE
    
        # Code snippet for Part 2 
#     t1 = Thread(target = io_bound, args =(SLEEP, )) 
#     t2 = Thread(target = io_bound, args =(SLEEP, )) 
#     t1.start() 
#     t2.start() 
#     t1.join() 
#     t2.join() 
    
    # Code snippet for Part 4 
    
# Code snippet for Part 6 
    p1 = Process(target = io_bound, args =(SLEEP, )) 
    p2 = Process(target = io_bound, args =(SLEEP, )) 
    p1.start() 
    p2.start() 
    p1.join() 
    p2.join() 
    
    
    end = time.time() 
    print('Time taken in seconds -', end - start)

# %%
'''
Ideally we would have access to an API however we are going to have to use 
growth hacking tactics in an automated fashion

'''
import time, os 
from threading import Thread, current_thread 
from multiprocessing import Process, current_process 
from multiprocessing import Pool

COUNT = 200000000

addresses = df["Address"]

browser = webdriver.Chrome()
browser.get("https://www.toronto.ca/city-government/data-research-maps/neighbourhoods-communities/ward-profiles/")


searcheElement = browser.find_element_by_css_selector("#js_input__address")
array = []

def seachAddress(addresses):
    for element in addresses:
        searcheElement.send_keys(element)
        searcheElement.submit() 
        time.sleep(1)
        try:
            linkElement = browser.find_element_by_css_selector(".map--result-text li:nth-child(1) > a")
            linkElement.click()
            searcheElement.clear() 
        except:
            try :
                wardNumElement = browser.find_element_by_css_selector(".map--ward-number")
                array.append(wardNumElement.text)
                searcheElement.clear()
                time.sleep(1)
            except:
                print("An exception occurred - Ward cannot be found")
                searcheElement.clear()
                array.append("0")

# seachAddress()     

# p = Pool(10)

# p.map(seachAddress())
# p.terminate()
# p.join()

# def cpu_bound(n): 
  
#     pid = os.getpid() 
#     threadName = current_thread().name 
#     processName = current_process().name 
  
#     print(f"{pid} * {processName} * {threadName} ---> Start counting...") 
  
#     while n>0: 
#         n -= 1
  
#     print(f"{pid} * {processName} * {threadName} ---> Finished counting...") 
    
# Code snippet for Part 5 

if __name__=="__main__": 
    p = Pool(10)
    
    start = time.time()
    
#     p.map(seachAddress())
#     p.terminate()
#     p.join()
    
    
    p1 = Process(target = seachAddress, args =(addresses, )) 
    p2 = Process(target = seachAddress, args =(addresses, )) 
    p1.start() 
    p2.start() 
    p1.join() 
    p2.join() 

    end = time.time() 
    print('Time taken in seconds -', end - start)
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# <ipython-input-12-fd5c39d1e633> in <module>
#      75     p1 = Process(target = seachAddress, args =(addresses, ))
#      76     p2 = Process(target = seachAddress, args =(addresses, ))
# ---> 77     p1.start()
#      78     p2.start()
#      79     p1.join()
#
# ~\Anaconda3\lib\multiprocessing\process.py in start(self)
#     110                'daemonic processes are not allowed to have children'
#     111         _cleanup()
# --> 112         self._popen = self._Popen(self)
#     113         self._sentinel = self._popen.sentinel
#     114         # Avoid a refcycle if the target function holds an indirect
#
# ~\Anaconda3\lib\multiprocessing\context.py in _Popen(process_obj)
#     221     @staticmethod
#     222     def _Popen(process_obj):
# --> 223         return _default_context.get_context().Process._Popen(process_obj)
#     224
#     225 class DefaultContext(BaseContext):
#
# ~\Anaconda3\lib\multiprocessing\context.py in _Popen(process_obj)
#     320         def _Popen(process_obj):
#     321             from .popen_spawn_win32 import Popen
# --> 322             return Popen(process_obj)
#     323
#     324     class SpawnContext(BaseContext):
#
# ~\Anaconda3\lib\multiprocessing\popen_spawn_win32.py in __init__(self, process_obj)
#      87             try:
#      88                 reduction.dump(prep_data, to_child)
# ---> 89                 reduction.dump(process_obj, to_child)
#      90             finally:
#      91                 set_spawning_popen(None)
#
# ~\Anaconda3\lib\multiprocessing\reduction.py in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#      61
#      62 #
#
# BrokenPipeError: [Errno 32] Broken pipe

# %%
from multiprocessing import Pool

Pool

# %%
def sum_up_to(number):
    return sum(range(1, number + 1))

a_pool = Pool()


result = a_pool.map(sum_up_to, range(10))

print(result)

# %%
from multiprocessing import Pool

def f(x):
    return x*x

if __name__ == '__main__':
    p = Pool(5)
    print(p.map(f, [1, 2, 3]))

# %%
import time, os 
from threading import Thread, current_thread 
from multiprocessing import Process, current_process 
  
  
COUNT = 200000000
SLEEP = 10
  
def io_bound(sec): 
  
    pid = os.getpid() 
    threadName = current_thread().name 
    processName = current_process().name 
  
    print(f"{pid} * {processName} * {threadName} \ 
        ---> Start sleeping...") 
    time.sleep(sec) 
    print(f"{pid} * {processName} * {threadName} \ 
        ---> Finished sleeping...") 
  
def cpu_bound(n): 
  
    pid = os.getpid() 
    threadName = current_thread().name 
    processName = current_process().name 
  
    print(f"{pid} * {processName} * {threadName} \ 
        ---> Start counting...") 
  
    while n>0: 
        n -= 1
  
    print(f"{pid} * {processName} * {threadName} \ 
        ---> Finished counting...") 
  
if __name__=="__main__": 
    start = time.time() 
  
    # YOUR CODE SNIPPET HERE 
    t1 = Thread(target = io_bound, args =(SLEEP, )) 
    t2 = Thread(target = io_bound, args =(SLEEP, )) 
    t1.start() 
    t2.start() 
    t1.join() 
    t2.join() 

    end = time.time() 
    print('Time taken in seconds -', end - start)

# %%
import queue

# %%
# first in first out
q = queue.Queue()

# %%
for i in range (7):
    q.put(i)

# %%
q.queue
# Out:
# deque([0, 1, 2, 3, 4, 5, 6])

# %%
import threading
import random

# %%
counter = 1
more_to_come = True

# %%
class Producer(threading.Thread):
    def __init__(self, queue):
        threading.Thread.__init__(self)
        self.queue = queue
    
    def run(self):
        global counter
        global more_to_come
        
        for i in range(5):
            time.sleep(random.randrange(2,5))
